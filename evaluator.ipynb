33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193922530 (185M) [application/octet-stream]
# Saving to: ‘./ref_batch/test/VIRTUAL_imagenet64_labeled.npz’
#
# VIRTUAL_imagenet64_ 100%[===================>] 184.94M  32.2MB/s    in 6.5s
#
# 2024-04-29 06:39:40 (28.5 MB/s) - ‘./ref_batch/test/VIRTUAL_imagenet64_labeled.npz’ saved [193922530/193922530]

# %%
import numpy as np
ref_path = f'./ref_batch/test/VIRTUAL_imagenet64_labeled.npz'
npzfile=np.load(ref_path)
npzfile.files
# Out:
# ['mu', 'sigma', 'mu_s', 'sigma_s', 'mu_clip', 'sigma_clip', 'arr_0']

# %%
np.savez('./ref_batch/test/VIRTUAL_imagenet64_labeled_100_witoutclip.npz',mu=npzfile['mu'],sigma=npzfile['sigma'],mu_s=npzfile['mu_s'],sigma_s=npzfile['sigma_s'],arr_0=npzfile['arr_0'][:100])

# %%
arr['mu']
# Out:
# array([0.19576394, 0.26630291, 0.2851155 , ..., 0.36868373, 0.3719117 ,
#        0.38509277])

# %%
arr['sigma']
# Out:
# array([[ 4.84855486e-02,  3.70024462e-03,  7.51887122e-03, ...,
#          7.56276606e-05, -4.80683624e-03,  4.62112194e-03],
#        [ 3.70024462e-03,  5.87727419e-02, -8.61939308e-04, ...,
#          3.95543079e-04, -4.94038473e-04,  2.53812927e-03],
#        [ 7.51887122e-03, -8.61939308e-04,  6.95033518e-02, ...,
#         -5.35369628e-03,  9.40427019e-03,  5.51410666e-03],
#        ...,
#        [ 7.56276606e-05,  3.95543079e-04, -5.35369628e-03, ...,
#          1.45193095e-01,  1.53591705e-02,  3.93643778e-03],
#        [-4.80683624e-03, -4.94038473e-04,  9.40427019e-03, ...,
#          1.53591705e-02,  1.30935296e-01, -8.10057792e-03],
#        [ 4.62112194e-03,  2.53812927e-03,  5.51410666e-03, ...,
#          3.93643778e-03, -8.10057792e-03,  1.29967266e-01]])

# %%
arr['mu_s']
# Out:
# array([0.92191845, 0.40854988, 0.6584112 , ..., 0.36797127, 0.16421476,
#        0.4947705 ], dtype=float32)

# %%
arr['sigma_s']
# Out:
# array([[ 1.13510993e+00, -4.78537473e-02, -1.57155694e-01, ...,
#          6.89138161e-03,  1.01134418e-02, -8.90000175e-03],
#        [-4.78537473e-02,  5.82613519e-01,  4.22115797e-02, ...,
#          5.14324874e-03,  1.95681862e-03, -1.10735617e-04],
#        [-1.57155694e-01,  4.22115797e-02,  1.00049386e+00, ...,
#          1.47734879e-02,  7.09129489e-04, -9.01891169e-03],
#        ...,
#        [ 6.89138161e-03,  5.14324874e-03,  1.47734879e-02, ...,
#          5.97319513e-01,  3.75554260e-02,  4.63308451e-02],
#        [ 1.01134418e-02,  1.95681862e-03,  7.09129489e-04, ...,
#          3.75554260e-02,  2.15972463e-01,  1.51789362e-02],
#        [-8.90000175e-03, -1.10735617e-04, -9.01891169e-03, ...,
#          4.63308451e-02,  1.51789362e-02,  6.21017937e-01]])

# %%
ref_path = f'./ref_batch/test/admnet_imagenet64.npz'
arr=np.load(ref_path)
arr.files
# Out:
# ['arr_0', 'arr_1']

# %%
arr['arr_1']
# Out:
# array([398, 290, 218, ..., 119, 136, 233])

# %%
# !python ./guided-diffusion-evaluator.py ./ref_batch/test/VIRTUAL_imagenet64_labeled_100_witoutclip.npz ./ref_batch/test/admnet_imagenet64.npz
# Out:
# 2024-04-29 08:22:01.019339: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-29 08:22:01.019388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-29 08:22:01.020737: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-29 08:22:01.027751: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
